# %%
# Importing libraries
import json
import time
from telnetlib import Telnet
import serial
import pandas as pd

import matplotlib.pyplot as plt
import matplotlib.animation as animation
import warnings
warnings.filterwarnings('ignore')

# %%
# Initializing keys, PORT and telnet configuration

ser = serial.Serial('COM4', 9600, timeout=1);
tn=Telnet('localhost',13854);

start=time.clock();

i=0;
tn.write(b'{"enableRawOutput": true, "format": "Json"}');

eSenseDict={'attention':0, 'meditation':0};
waveDict={'lowGamma':0, 'highGamma':0, 'highAlpha':0, 'delta':0, 'highBeta':0, 'lowAlpha':0, 'lowBeta':0, 'theta':0};
signalLevel=0;

# %%
EEGDATAFRAME = pd.DataFrame(columns=['Time', 'Attention', 'Meditation','Blink_Strength'])


while i<100:
    eeg_data = []

    blinkStrength=0;

    line=tn.read_until(b'\r');
#     print(line);

    if len(line) > 20:
        timediff=time.clock()-start;
        dict=json.loads((line));
        print(line);
        if "poorSignalLevel" in dict:
            signalLevel=dict['poorSignalLevel'];
        if "blinkStrength" in dict:
            blinkStrength=dict['blinkStrength'];
        if "eegPower" in dict:
            waveDict=dict['eegPower'];
            print(waveDict,'waveDict');
            eSenseDict=dict['eSense'];
            print(eSenseDict,'eSenseDict');

        attentionStr=str(eSenseDict['attention']);
        meditationStr=str(eSenseDict['meditation']);
        blinkStrengthStr=str(blinkStrength);
        seconds = time.time();

        eeg_data.append({'Time': seconds,'Attention': attentionStr, 'Meditation': meditationStr, 'Blink_Strength':blinkStrengthStr})
        print(eeg_data);
        eeg_df = pd.DataFrame(eeg_data)
        EEGDATAFRAME = EEGDATAFRAME.append(eeg_df, ignore_index=True)
#         print(EEGDATAFRAME) 
        EEGDATAFRAME.to_csv('eegdata.csv',index=True)

#         print("Attention: " + attentionStr);
#         print("Meditation: " + meditationStr);
#         print("Blink Strength: " + blinkStrengthStr);
#         print("");

        attentionInt = int(attentionStr)
        if attentionInt > 70:
            ser.write(str.encode('a'));
            time.sleep(1)

        meditationInt = int(meditationStr)
        if meditationInt > 70:
            ser.write(str.encode('b'));
            time.sleep(1)

        blinkStrengthInt = int(blinkStrengthStr)
        if blinkStrengthInt > 1:
            ser.write(str.encode('c'));
            time.sleep(1)

ser.close();
tn.close();
# Out:
# b'{"poorSignalLevel":200,"status":"scanning"}\r'
# [{'Time': 1618908637.857213, 'Attention': '0', 'Meditation': '0', 'Blink_Strength': '0'}]
# b'{"poorSignalLevel":200,"status":"scanning"}\r'
# [{'Time': 1618908638.0877995, 'Attention': '0', 'Meditation': '0', 'Blink_Strength': '0'}]
# b'{"poorSignalLevel":200,"status":"scanning"}\r'
# [{'Time': 1618908638.0978146, 'Attention': '0', 'Meditation': '0', 'Blink_Strength': '0'}]
# b'{"poorSignalLevel":200,"status":"scanning"}\r'
# [{'Time': 1618908638.1087546, 'Attention': '0', 'Meditation': '0', 'Blink_Strength': '0'}]
# b'{"poorSignalLevel":200,"status":"scanning"}\r'
# [{'Time': 1618908638.1187193, 'Attention': '0', 'Meditation': '0', 'Blink_Strength': '0'}]
# b'{"poorSignalLevel":200,"status":"scanning"}\r'
# [{'Time': 1618908638.1276922, 'Attention': '0', 'Meditation': '0', 'Blink_Strength': '0'}]
# b'{"poorSignalLevel":200,"status":"scanning"}\r'
# [{'Time': 1618908638.1366682, 'Attention': '0', 'Meditation': '0', 'Blink_Strength': '0'}]
# b'{"poorSignalLevel":200,"status":"scanning"}\r'
# [{'Time': 1618908638.1446514, 'Attention': '0', 'Meditation': '0', 'Blink_Strength': '0'}]
# b'{"poorSignalLevel":200,"status":"scanning"}\r'
# [{'Time': 1618908638.1526248, 'Attention': '0', 'Meditation': '0', 'Blink_Strength': '0'}]
# b'{"poorSignalLevel":200,"status":"scanning"}\r'
# [{'Time': 1618908638.1616006, 'Attention': '0', 'Meditation': '0', 'Blink_Strength': '0'}]
# b'{"poorSignalLevel":200,"status":"scanning"}\r'
# [{'Time': 1618908638.171573, 'Attention': '0', 'Meditation': '0', 'Blink_Strength': '0'}]
# b'{"eSense":{"attention":0,"meditation":0},"eegPower":{"delta":729607,"theta":494810,"lowAlpha":85125,"highAlpha":100624,"lowBeta":40111,"highBeta":9440,"lowGamma":10021,"highGamma":24769},"poorSignalLevel":0}\r'
# {'delta': 729607, 'theta': 494810, 'lowAlpha': 85125, 'highAlpha': 100624, 'lowBeta': 40111, 'highBeta': 9440, 'lowGamma': 10021, 'highGamma': 24769} waveDict
# {'attention': 0, 'meditation': 0} eSenseDict
# [{'Time': 1618908638.2005088, 'Attention': '0', 'Meditation': '0', 'Blink_Strength': '0'}]
# b'{"eSense":{"attention":0,"meditation":0},"eegPower":{"delta":835120,"theta":824286,"lowAlpha":46392,"highAlpha":41763,"lowBeta":27596,"highBeta":11189,"lowGamma":21752,"highGamma":25357},"poorSignalLevel":0}\r'
# {'delta': 835120, 'theta': 824286, 'lowAlpha': 46392, 'highAlpha': 41763, 'lowBeta': 27596, 'highBeta': 11189, 'lowGamma': 21752, 'highGamma': 25357} waveDict
# {'attention': 0, 'meditation': 0} eSenseDict
# [{'Time': 1618908638.2244315, 'Attention': '0', 'Meditation': '0', 'Blink_Strength': '0'}]
# b'{"blinkStrength":31}\r'
# [{'Time': 1618908638.2453756, 'Attention': '0', 'Meditation': '0', 'Blink_Strength': '31'}]
# b'{"eSense":{"attention":0,"meditation":0},"eegPower":{"delta":1725134,"theta":552852,"lowAlpha":11162,"highAlpha":138194,"lowBeta":27867,"highBeta":26877,"lowGamma":18796,"highGamma":17888},"poorSignalLevel":0}\r'
# {'delta': 1725134, 'theta': 552852, 'lowAlpha': 11162, 'highAlpha': 138194, 'lowBeta': 27867, 'highBeta': 26877, 'lowGamma': 18796, 'highGamma': 17888} waveDict
# {'attention': 0, 'meditation': 0} eSenseDict
# [{'Time': 1618908639.2562814, 'Attention': '0', 'Meditation': '0', 'Blink_Strength': '0'}]
# b'{"eSense":{"attention":50,"meditation":53},"eegPower":{"delta":463748,"theta":28940,"lowAlpha":9184,"highAlpha":4531,"lowBeta":1661,"highBeta":1639,"lowGamma":1243,"highGamma":1356},"poorSignalLevel":0}\r'
# {'delta': 463748, 'theta': 28940, 'lowAlpha': 9184, 'highAlpha': 4531, 'lowBeta': 1661, 'highBeta': 1639, 'lowGamma': 1243, 'highGamma': 1356} waveDict
# {'attention': 50, 'meditation': 53} eSenseDict
# [{'Time': 1618908639.2772238, 'Attention': '50', 'Meditation': '53', 'Blink_Strength': '0'}]
# b'{"blinkStrength":32}\r'
# [{'Time': 1618908639.2891915, 'Attention': '50', 'Meditation': '53', 'Blink_Strength': '32'}]
# b'{"eSense":{"attention":77,"meditation":66},"eegPower":{"delta":264186,"theta":17176,"lowAlpha":1937,"highAlpha":5378,"lowBeta":3589,"highBeta":1850,"lowGamma":1020,"highGamma":1669},"poorSignalLevel":0}\r'
# {'delta': 264186, 'theta': 17176, 'lowAlpha': 1937, 'highAlpha': 5378, 'lowBeta': 3589, 'highBeta': 1850, 'lowGamma': 1020, 'highGamma': 1669} waveDict
# {'attention': 77, 'meditation': 66} eSenseDict
# [{'Time': 1618908640.3197262, 'Attention': '77', 'Meditation': '66', 'Blink_Strength': '0'}]
# b'{"eSense":{"attention":94,"meditation":70},"eegPower":{"delta":811450,"theta":82762,"lowAlpha":4237,"highAlpha":17896,"lowBeta":14451,"highBeta":6028,"lowGamma":4291,"highGamma":6604},"poorSignalLevel":0}\r'
# {'delta': 811450, 'theta': 82762, 'lowAlpha': 4237, 'highAlpha': 17896, 'lowBeta': 14451, 'highBeta': 6028, 'lowGamma': 4291, 'highGamma': 6604} waveDict
# {'attention': 94, 'meditation': 70} eSenseDict
# [{'Time': 1618908641.3416278, 'Attention': '94', 'Meditation': '70', 'Blink_Strength': '0'}]
# b'{"eSense":{"attention":100,"meditation":74},"eegPower":{"delta":899041,"theta":73927,"lowAlpha":1289,"highAlpha":44698,"lowBeta":3369,"highBeta":16618,"lowGamma":1271,"highGamma":6108},"poorSignalLevel":0}\r'
# {'delta': 899041, 'theta': 73927, 'lowAlpha': 1289, 'highAlpha': 44698, 'lowBeta': 3369, 'highBeta': 16618, 'lowGamma': 1271, 'highGamma': 6108} waveDict
# {'attention': 100, 'meditation': 74} eSenseDict
# [{'Time': 1618908642.3666325, 'Attention': '100', 'Meditation': '74', 'Blink_Strength': '0'}]
# b'{"eSense":{"attention":100,"meditation":63},"eegPower":{"delta":726873,"theta":580854,"lowAlpha":45289,"highAlpha":43442,"lowBeta":42674,"highBeta":45065,"lowGamma":7081,"highGamma":32757},"poorSignalLevel":0}\r'
# {'delta': 726873, 'theta': 580854, 'lowAlpha': 45289, 'highAlpha': 43442, 'lowBeta': 42674, 'highBeta': 45065, 'lowGamma': 7081, 'highGamma': 32757} waveDict
# {'attention': 100, 'meditation': 63} eSenseDict
# [{'Time': 1618908644.4307227, 'Attention': '100', 'Meditation': '63', 'Blink_Strength': '0'}]
# b'{"eSense":{"attention":100,"meditation":70},"eegPower":{"delta":666204,"theta":78363,"lowAlpha":31275,"highAlpha":4762,"lowBeta":8703,"highBeta":6208,"lowGamma":5020,"highGamma":6041},"poorSignalLevel":0}\r'
# {'delta': 666204, 'theta': 78363, 'lowAlpha': 31275, 'highAlpha': 4762, 'lowBeta': 8703, 'highBeta': 6208, 'lowGamma': 5020, 'highGamma': 6041} waveDict
# {'attention': 100, 'meditation': 70} eSenseDict
# [{'Time': 1618908645.495385, 'Attention': '100', 'Meditation': '70', 'Blink_Strength': '0'}]
# b'{"eSense":{"attention":93,"meditation":78},"eegPower":{"delta":96458,"theta":7756,"lowAlpha":5971,"highAlpha":5361,"lowBeta":4232,"highBeta":1846,"lowGamma":360,"highGamma":2373},"poorSignalLevel":0}\r'
# {'delta': 96458, 'theta': 7756, 'lowAlpha': 5971, 'highAlpha': 5361, 'lowBeta': 4232, 'highBeta': 1846, 'lowGamma': 360, 'highGamma': 2373} waveDict
# {'attention': 93, 'meditation': 78} eSenseDict
# [{'Time': 1618908646.5254352, 'Attention': '93', 'Meditation': '78', 'Blink_Strength': '0'}]
# b'{"eSense":{"attention":83,"meditation":96},"eegPower":{"delta":831600,"theta":77023,"lowAlpha":1917,"highAlpha":12560,"lowBeta":4639,"highBeta":5197,"lowGamma":2097,"highGamma":6642},"poorSignalLevel":0}\r'
# {'delta': 831600, 'theta': 77023, 'lowAlpha': 1917, 'highAlpha': 12560, 'lowBeta': 4639, 'highBeta': 5197, 'lowGamma': 2097, 'highGamma': 6642} waveDict
# {'attention': 83, 'meditation': 96} eSenseDict
# [{'Time': 1618908648.5845153, 'Attention': '83', 'Meditation': '96', 'Blink_Strength': '0'}]
# b'{"blinkStrength":36}\r'
# [{'Time': 1618908650.595691, 'Attention': '83', 'Meditation': '96', 'Blink_Strength': '36'}]
# b'{"blinkStrength":54}\r'
# [{'Time': 1618908653.614161, 'Attention': '83', 'Meditation': '96', 'Blink_Strength': '54'}]
# b'{"eSense":{"attention":70,"meditation":77},"eegPower":{"delta":617857,"theta":248089,"lowAlpha":24243,"highAlpha":15361,"lowBeta":26654,"highBeta":6188,"lowGamma":4389,"highGamma":6204},"poorSignalLevel":0}\r'
# {'delta': 617857, 'theta': 248089, 'lowAlpha': 24243, 'highAlpha': 15361, 'lowBeta': 26654, 'highBeta': 6188, 'lowGamma': 4389, 'highGamma': 6204} waveDict
# {'attention': 70, 'meditation': 77} eSenseDict
# [{'Time': 1618908656.6453302, 'Attention': '70', 'Meditation': '77', 'Blink_Strength': '0'}]
# b'{"eSense":{"attention":63,"meditation":51},"eegPower":{"delta":53971,"theta":189682,"lowAlpha":11625,"highAlpha":26041,"lowBeta":6410,"highBeta":9623,"lowGamma":5960,"highGamma":5283},"poorSignalLevel":0}\r'
# {'delta': 53971, 'theta': 189682, 'lowAlpha': 11625, 'highAlpha': 26041, 'lowBeta': 6410, 'highBeta': 9623, 'lowGamma': 5960, 'highGamma': 5283} waveDict
# {'attention': 63, 'meditation': 51} eSenseDict
# [{'Time': 1618908657.6929035, 'Attention': '63', 'Meditation': '51', 'Blink_Strength': '0'}]
# b'{"eSense":{"attention":57,"meditation":35},"eegPower":{"delta":1319218,"theta":244385,"lowAlpha":95731,"highAlpha":29027,"lowBeta":68964,"highBeta":28412,"lowGamma":11726,"highGamma":19598},"poorSignalLevel":0}\r'
# {'delta': 1319218, 'theta': 244385, 'lowAlpha': 95731, 'highAlpha': 29027, 'lowBeta': 68964, 'highBeta': 28412, 'lowGamma': 11726, 'highGamma': 19598} waveDict
# {'attention': 57, 'meditation': 35} eSenseDict
# [{'Time': 1618908657.7228506, 'Attention': '57', 'Meditation': '35', 'Blink_Strength': '0'}]
# b'{"eSense":{"attention":60,"meditation":47},"eegPower":{"delta":1995595,"theta":90635,"lowAlpha":35298,"highAlpha":15983,"lowBeta":14773,"highBeta":10215,"lowGamma":2749,"highGamma":6775},"poorSignalLevel":0}\r'
# {'delta': 1995595, 'theta': 90635, 'lowAlpha': 35298, 'highAlpha': 15983, 'lowBeta': 14773, 'highBeta': 10215, 'lowGamma': 2749, 'highGamma': 6775} waveDict
# {'attention': 60, 'meditation': 47} eSenseDict
# [{'Time': 1618908657.7537408, 'Attention': '60', 'Meditation': '47', 'Blink_Strength': '0'}]
# b'{"eSense":{"attention":60,"meditation":48},"eegPower":{"delta":2008019,"theta":754605,"lowAlpha":47214,"highAlpha":76955,"lowBeta":56064,"highBeta":18726,"lowGamma":21062,"highGamma":17913},"poorSignalLevel":0}\r'
# {'delta': 2008019, 'theta': 754605, 'lowAlpha': 47214, 'highAlpha': 76955, 'lowBeta': 56064, 'highBeta': 18726, 'lowGamma': 21062, 'highGamma': 17913} waveDict
# {'attention': 60, 'meditation': 48} eSenseDict
# [{'Time': 1618908657.7807016, 'Attention': '60', 'Meditation': '48', 'Blink_Strength': '0'}]
# b'{"eSense":{"attention":61,"meditation":57},"eegPower":{"delta":1148646,"theta":49817,"lowAlpha":12785,"highAlpha":13766,"lowBeta":1447,"highBeta":3637,"lowGamma":5201,"highGamma":4269},"poorSignalLevel":0}\r'
# {'delta': 1148646, 'theta': 49817, 'lowAlpha': 12785, 'highAlpha': 13766, 'lowBeta': 1447, 'highBeta': 3637, 'lowGamma': 5201, 'highGamma': 4269} waveDict
# {'attention': 61, 'meditation': 57} eSenseDict
# [{'Time': 1618908657.80261, 'Attention': '61', 'Meditation': '57', 'Blink_Strength': '0'}]
# b'{"eSense":{"attention":53,"meditation":50},"eegPower":{"delta":311211,"theta":105349,"lowAlpha":14330,"highAlpha":6264,"lowBeta":2287,"highBeta":5615,"lowGamma":2633,"highGamma":2831},"poorSignalLevel":0}\r'
# {'delta': 311211, 'theta': 105349, 'lowAlpha': 14330, 'highAlpha': 6264, 'lowBeta': 2287, 'highBeta': 5615, 'lowGamma': 2633, 'highGamma': 2831} waveDict
# {'attention': 53, 'meditation': 50} eSenseDict
# [{'Time': 1618908657.8255787, 'Attention': '53', 'Meditation': '50', 'Blink_Strength': '0'}]
# b'{"eSense":{"attention":48,"meditation":38},"eegPower":{"delta":1408524,"theta":123420,"lowAlpha":3302,"highAlpha":23112,"lowBeta":3349,"highBeta":2338,"lowGamma":2193,"highGamma":5109},"poorSignalLevel":0}\r'
# {'delta': 1408524, 'theta': 123420, 'lowAlpha': 3302, 'highAlpha': 23112, 'lowBeta': 3349, 'highBeta': 2338, 'lowGamma': 2193, 'highGamma': 5109} waveDict
# {'attention': 48, 'meditation': 38} eSenseDict
# [{'Time': 1618908657.8664382, 'Attention': '48', 'Meditation': '38', 'Blink_Strength': '0'}]
# b'{"blinkStrength":42}\r'
# [{'Time': 1618908657.896357, 'Attention': '48', 'Meditation': '38', 'Blink_Strength': '42'}]
# b'{"eSense":{"attention":51,"meditation":21},"eegPower":{"delta":625775,"theta":548470,"lowAlpha":7643,"highAlpha":63263,"lowBeta":59532,"highBeta":35850,"lowGamma":9400,"highGamma":16977},"poorSignalLevel":0}\r'
# {'delta': 625775, 'theta': 548470, 'lowAlpha': 7643, 'highAlpha': 63263, 'lowBeta': 59532, 'highBeta': 35850, 'lowGamma': 9400, 'highGamma': 16977} waveDict
# {'attention': 51, 'meditation': 21} eSenseDict
# [{'Time': 1618908658.9196563, 'Attention': '51', 'Meditation': '21', 'Blink_Strength': '0'}]
# b'{"blinkStrength":43}\r'
# [{'Time': 1618908658.9535675, 'Attention': '51', 'Meditation': '21', 'Blink_Strength': '43'}]
# b'{"eSense":{"attention":56,"meditation":23},"eegPower":{"delta":489590,"theta":222811,"lowAlpha":31356,"highAlpha":27232,"lowBeta":35730,"highBeta":18807,"lowGamma":3535,"highGamma":4869},"poorSignalLevel":0}\r'
# {'delta': 489590, 'theta': 222811, 'lowAlpha': 31356, 'highAlpha': 27232, 'lowBeta': 35730, 'highBeta': 18807, 'lowGamma': 3535, 'highGamma': 4869} waveDict
# {'attention': 56, 'meditation': 23} eSenseDict
# [{'Time': 1618908659.9865375, 'Attention': '56', 'Meditation': '23', 'Blink_Strength': '0'}]
# b'{"eSense":{"attention":80,"meditation":35},"eegPower":{"delta":631708,"theta":130896,"lowAlpha":7270,"highAlpha":22786,"lowBeta":4520,"highBeta":8839,"lowGamma":1308,"highGamma":2461},"poorSignalLevel":0}\r'
# {'delta': 631708, 'theta': 130896, 'lowAlpha': 7270, 'highAlpha': 22786, 'lowBeta': 4520, 'highBeta': 8839, 'lowGamma': 1308, 'highGamma': 2461} waveDict
# {'attention': 80, 'meditation': 35} eSenseDict
# [{'Time': 1618908660.5255063, 'Attention': '80', 'Meditation': '35', 'Blink_Strength': '0'}]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-30e4245bcc39> in <module>
#      44         if attentionInt > 70:
#      45             ser.write(str.encode('a'));
# ---> 46             time.sleep(1)
#      47
#      48         meditationInt = int(meditationStr)
#
# KeyboardInterrupt:
